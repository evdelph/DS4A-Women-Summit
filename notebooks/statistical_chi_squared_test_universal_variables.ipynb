# %% [markdown]
# # Anxiety/depression and chi-squared statistical test

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, chi2

warnings.filterwarnings("ignore")

# %%
df_pulse = pd.read_csv('../data/interim/pulse2020_puf_all.csv')

# %%
df_pulse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197365 entries, 0 to 1197364
# Columns: 207 entries, SCRAM to depression_disorder
# dtypes: bool(2), float64(203), object(2)
# memory usage: 1.8+ GB

# %%
df_pulse.columns
# Out:
# Index(['SCRAM', 'WEEK', 'EST_ST', 'EST_MSA', 'PWEIGHT', 'ABIRTH_YEAR',
#        'EGENDER', 'AGENDER', 'RHISPANIC', 'AHISPANIC',
#        ...
#        'PSWHYCHG3', 'PSWHYCHG4', 'PSWHYCHG5', 'PSWHYCHG6', 'PSWHYCHG7',
#        'PSWHYCHG8', 'PSWHYCHG9', 'AGE', 'anxiety_disorder',
#        'depression_disorder'],
#       dtype='object', length=207)

# %% [markdown]
# ### Dataset post-data wrangling

# %%
df_pulse.head()
# Out:
#                        SCRAM        WEEK  EST_ST  EST_MSA      PWEIGHT  \
# 0  V010000001S10011099370111  2020-04-23    47.0      NaN  1973.489532
# 1  V010000001S10011900470112  2020-04-23     1.0      NaN  1929.488419
# 2  V010000001S18010744940111  2020-04-23    26.0      NaN  1526.612380
# 3  V010000001S37010301340112  2020-04-23     1.0      NaN  2734.635354
# 4  V010000001S37010480340111  2020-04-23     1.0      NaN   681.211425
#
#    ABIRTH_YEAR  EGENDER  AGENDER  RHISPANIC  AHISPANIC  ...  PSWHYCHG3  \
# 0          2.0      2.0      2.0        1.0        2.0  ...        NaN
# 1          2.0      1.0      2.0        1.0        2.0  ...        NaN
# 2          2.0      2.0      2.0        1.0        2.0  ...        NaN
# 3          2.0      1.0      2.0        1.0        2.0  ...        NaN
# 4          2.0      2.0      2.0        1.0        2.0  ...        NaN
#
#    PSWHYCHG4  PSWHYCHG5  PSWHYCHG6  PSWHYCHG7  PSWHYCHG8  PSWHYCHG9   AGE  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  34.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN  65.0
# 2        NaN        NaN        NaN        NaN        NaN        NaN  44.0
# 3        NaN        NaN        NaN        NaN        NaN        NaN  56.0
# 4        NaN        NaN        NaN        NaN        NaN        NaN  57.0
#
#    anxiety_disorder  depression_disorder
# 0              True                False
# 1              True                 True
# 2             False                False
# 3              True                 True
# 4             False                False
#
# [5 rows x 207 columns]

# %%
df_pulse.shape
# Out:
# (1197365, 207)

# %% [markdown]
# For a quick analysis, we are going to ignore the secundary variables and using only those variables asked to the whole sample:

# %%
secondary_columns = [
                    'KINDWORK',
                    'RSNNOWRK',
                    'UNEMPPAY',
                    'FOODSUFRSN1',
                    'FOODSUFRSN2',
                    'FOODSUFRSN3',
                    'FOODSUFRSN4',
                    'FOODSUFRSN5',
                    'WHEREFREE1',
                    'WHEREFREE2',
                    'WHEREFREE3',
                    'WHEREFREE4',
                    'WHEREFREE5',
                    'WHEREFREE6',
                    'WHEREFREE7',
                    'FOODCONF',
                    'MORTLMTH',
                    'MORTCONF',
                    'TEACH1',
                    'TEACH2',
                    'TEACH3',
                    'TEACH4',
                    'TEACH5',
                    'COMPAVAIL',
                    'COMP1',
                    'COMP2',
                    'COMP3',
                    'INTRNTAVAIL',
                    'INTRNT1',
                    'INTRNT2',
                    'INTRNT3',
                    'TSCHLHRS',
                    'TTCH_HRS'
                    ]

# %%
print('Number of contextual variables: {}'.format(len(secondary_columns)))
# Out:
# Number of contextual variables: 33

# %% [markdown]
# Deleting contextual variables

# %%
df_universal = df_pulse.drop(columns=secondary_columns)

# %%
df_universal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197365 entries, 0 to 1197364
# Columns: 174 entries, SCRAM to depression_disorder
# dtypes: bool(2), float64(170), object(2)
# memory usage: 1.5+ GB

# %% [markdown]
# We are going to do a chi-squared test to find the universal variables more related to the Anxiety and Depression outcomes, calculated previously based on the variables `ANXIOUS`, `INTEREST`, `DOWN` and `WORRY`.

# %% [markdown]
# Drop columns when they have lost up to 75% of information

# %%
threshold = int(0.75*len(df_universal))
threshold
# Out:
# 898023

# %%
df_universal1 = df_universal.dropna(axis=1, thresh=threshold)
df_universal1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197365 entries, 0 to 1197364
# Data columns (total 46 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   SCRAM                1197365 non-null  object
#  1   WEEK                 1197365 non-null  object
#  2   EST_ST               1197365 non-null  float64
#  3   PWEIGHT              1197365 non-null  float64
#  4   ABIRTH_YEAR          1197365 non-null  float64
#  5   EGENDER              1197365 non-null  float64
#  6   AGENDER              1197365 non-null  float64
#  7   RHISPANIC            1197365 non-null  float64
#  8   AHISPANIC            1197365 non-null  float64
#  9   RRACE                1197365 non-null  float64
#  10  ARACE                1197365 non-null  float64
#  11  EEDUC                1197365 non-null  float64
#  12  AEDUC                1197365 non-null  float64
#  13  MS                   1188120 non-null  float64
#  14  THHLD_NUMPER         1197365 non-null  float64
#  15  AHHLD_NUMPER         1197365 non-null  float64
#  16  THHLD_NUMKID         1197365 non-null  float64
#  17  AHHLD_NUMKID         1197365 non-null  float64
#  18  THHLD_NUMADLT        1197365 non-null  float64
#  19  WRKLOSS              1190853 non-null  float64
#  20  EXPCTLOSS            1189437 non-null  float64
#  21  ANYWORK              1190619 non-null  float64
#  22  PRIFOODSUF           1166543 non-null  float64
#  23  CURFOODSUF           1165766 non-null  float64
#  24  FREEFOOD             1161768 non-null  float64
#  25  TSPNDFOOD            1073137 non-null  float64
#  26  TSPNDPRPD            1064031 non-null  float64
#  27  HLTHSTATUS           1085093 non-null  float64
#  28  ANXIOUS              1083903 non-null  float64
#  29  WORRY                1083252 non-null  float64
#  30  INTEREST             1082645 non-null  float64
#  31  DOWN                 1083555 non-null  float64
#  32  HLTHINS1             1034830 non-null  float64
#  33  HLTHINS2             951680 non-null   float64
#  34  HLTHINS3             974533 non-null   float64
#  35  HLTHINS4             927947 non-null   float64
#  36  HLTHINS5             919926 non-null   float64
#  37  HLTHINS6             915961 non-null   float64
#  38  HLTHINS7             906492 non-null   float64
#  39  DELAY                1069395 non-null  float64
#  40  NOTGET               1070725 non-null  float64
#  41  TENURE               1065564 non-null  float64
#  42  INCOME               1028218 non-null  float64
#  43  AGE                  1197365 non-null  float64
#  44  anxiety_disorder     1197365 non-null  bool
#  45  depression_disorder  1197365 non-null  bool
# dtypes: bool(2), float64(42), object(2)
# memory usage: 404.2+ MB

# %% [markdown]
# Drop ID, WEEK, and variables used to calculate the outcomes of the chi-squared test (`ANXIOUS`, `WORRY` were used to estimate the ANXIETY DISORDER and `DOWN`, `INTEREST` were used to score DEPRESSION DISORDER).

# %%
df_universal1.drop(columns=['SCRAM', 'WEEK', 'ANXIOUS', 'WORRY', 'DOWN', 'INTEREST'], inplace=True)

# %% [markdown]
# Drop duplicates and missing datapoints

# %%
df_universal1.drop_duplicates(inplace=True)

# %%
df_universal1.dropna(inplace=True)

# %%
df_universal1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817105 entries, 0 to 1197364
# Data columns (total 40 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   EST_ST               817105 non-null  float64
#  1   PWEIGHT              817105 non-null  float64
#  2   ABIRTH_YEAR          817105 non-null  float64
#  3   EGENDER              817105 non-null  float64
#  4   AGENDER              817105 non-null  float64
#  5   RHISPANIC            817105 non-null  float64
#  6   AHISPANIC            817105 non-null  float64
#  7   RRACE                817105 non-null  float64
#  8   ARACE                817105 non-null  float64
#  9   EEDUC                817105 non-null  float64
#  10  AEDUC                817105 non-null  float64
#  11  MS                   817105 non-null  float64
#  12  THHLD_NUMPER         817105 non-null  float64
#  13  AHHLD_NUMPER         817105 non-null  float64
#  14  THHLD_NUMKID         817105 non-null  float64
#  15  AHHLD_NUMKID         817105 non-null  float64
#  16  THHLD_NUMADLT        817105 non-null  float64
#  17  WRKLOSS              817105 non-null  float64
#  18  EXPCTLOSS            817105 non-null  float64
#  19  ANYWORK              817105 non-null  float64
#  20  PRIFOODSUF           817105 non-null  float64
#  21  CURFOODSUF           817105 non-null  float64
#  22  FREEFOOD             817105 non-null  float64
#  23  TSPNDFOOD            817105 non-null  float64
#  24  TSPNDPRPD            817105 non-null  float64
#  25  HLTHSTATUS           817105 non-null  float64
#  26  HLTHINS1             817105 non-null  float64
#  27  HLTHINS2             817105 non-null  float64
#  28  HLTHINS3             817105 non-null  float64
#  29  HLTHINS4             817105 non-null  float64
#  30  HLTHINS5             817105 non-null  float64
#  31  HLTHINS6             817105 non-null  float64
#  32  HLTHINS7             817105 non-null  float64
#  33  DELAY                817105 non-null  float64
#  34  NOTGET               817105 non-null  float64
#  35  TENURE               817105 non-null  float64
#  36  INCOME               817105 non-null  float64
#  37  AGE                  817105 non-null  float64
#  38  anxiety_disorder     817105 non-null  bool
#  39  depression_disorder  817105 non-null  bool
# dtypes: bool(2), float64(38)
# memory usage: 244.7 MB

# %% [markdown]
# ## Selecting K Best features for Anxiety disorders

# %%
np.random.seed(100)

y = df_universal1.anxiety_disorder
X = df_universal1.drop(columns=['anxiety_disorder', 'depression_disorder'])
print(X.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100, test_size=0.3)
print(X_train.shape)
# Out:
# (817105, 38)
# (571973, 38)

# %%
K = 20 # select 20 features
sel_chi2 = SelectKBest(chi2, k=K)    
X_train_chi2 = sel_chi2.fit_transform(X_train, y_train)

# %%
set_chi2_list = list(sel_chi2.get_support())
columns_list = list(df_universal1.drop(columns=['anxiety_disorder', 'depression_disorder']))

# %%
dictionary_anxiety_variables = {'variable': columns_list, 'chi-squared scores': np.round(sel_chi2.scores_, 3), 'selected': set_chi2_list}
df_chiSelectionAnxiety = pd.DataFrame(dictionary_anxiety_variables)

# %%
df_chiSelectionAnxiety.sort_values('chi-squared scores', ascending=False)
# Out:
#          variable  chi-squared scores  selected
# 1         PWEIGHT         2800628.420      True
# 37            AGE           78597.324      True
# 23      TSPNDFOOD           21723.779      True
# 25     HLTHSTATUS           17556.675      True
# 21     CURFOODSUF           14106.833      True
# 36         INCOME           13901.842      True
# 11             MS            9692.085      True
# 20     PRIFOODSUF            7443.217      True
# 33          DELAY            3900.684      True
# 34         NOTGET            3549.190      True
# 35         TENURE            3403.663      True
# 17        WRKLOSS            2711.569      True
# 18      EXPCTLOSS            2505.571      True
# 9           EEDUC            1483.915      True
# 14   THHLD_NUMKID            1478.439      True
# 3         EGENDER             956.309      True
# 0          EST_ST             663.924      True
# 28       HLTHINS3             547.011      True
# 12   THHLD_NUMPER             515.539      True
# 29       HLTHINS4             386.691      True
# 26       HLTHINS1             280.882     False
# 7           RRACE             279.533     False
# 24      TSPNDPRPD             271.812     False
# 19        ANYWORK             146.375     False
# 5       RHISPANIC              86.260     False
# 22       FREEFOOD              70.245     False
# 27       HLTHINS2              25.405     False
# 16  THHLD_NUMADLT              18.580     False
# 30       HLTHINS5              11.535     False
# 31       HLTHINS6               2.969     False
# 8           ARACE               1.495     False
# 32       HLTHINS7               0.360     False
# 13   AHHLD_NUMPER               0.028     False
# 4         AGENDER               0.005     False
# 6       AHISPANIC               0.002     False
# 15   AHHLD_NUMKID               0.001     False
# 2     ABIRTH_YEAR               0.001     False
# 10          AEDUC               0.000     False

# %% [markdown]
# ## Select K-Best features for Depression Disorders

# %%
np.random.seed(100)

y = df_universal1.depression_disorder
X = df_universal1.drop(columns=['anxiety_disorder', 'depression_disorder'])
print(X.shape)


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100, test_size=0.3)
print(X_train.shape)
# Out:
# (817105, 38)
# (571973, 38)

# %%
sel_chi2 = SelectKBest(chi2, k=K)
X_train_chi2 = sel_chi2.fit_transform(X_train, y_train)

# %%
set_chi2_list = list(sel_chi2.get_support())

# %%
dictionary_anxiety_variables = {'variable': columns_list, 'chi-squared scores': np.round(sel_chi2.scores_, 3), 'selected': set_chi2_list}
df_chiSelectionDepression = pd.DataFrame(dictionary_anxiety_variables)

# %%
df_chiSelectionDepression.sort_values('chi-squared scores', ascending=False)
# Out:
#          variable  chi-squared scores  selected
# 1         PWEIGHT        1.634311e+07      True
# 37            AGE        4.340884e+04      True
# 36         INCOME        2.256840e+04      True
# 25     HLTHSTATUS        2.185051e+04      True
# 21     CURFOODSUF        1.603030e+04      True
# 11             MS        1.494516e+04      True
# 20     PRIFOODSUF        9.162641e+03      True
# 23      TSPNDFOOD        5.485259e+03      True
# 9           EEDUC        3.589818e+03      True
# 35         TENURE        3.065050e+03      True
# 34         NOTGET        2.902017e+03      True
# 33          DELAY        2.667563e+03      True
# 17        WRKLOSS        2.091834e+03      True
# 18      EXPCTLOSS        1.988579e+03      True
# 24      TSPNDPRPD        1.654004e+03      True
# 26       HLTHINS1        7.730320e+02      True
# 19        ANYWORK        6.106210e+02      True
# 0          EST_ST        5.819870e+02      True
# 7           RRACE        5.484580e+02      True
# 29       HLTHINS4        4.522690e+02      True
# 3         EGENDER        2.512920e+02     False
# 28       HLTHINS3        1.642810e+02     False
# 5       RHISPANIC        8.276700e+01     False
# 22       FREEFOOD        6.031200e+01     False
# 27       HLTHINS2        1.635000e+01     False
# 30       HLTHINS5        5.720000e+00     False
# 14   THHLD_NUMKID        5.712000e+00     False
# 8           ARACE        1.660000e+00     False
# 12   THHLD_NUMPER        1.248000e+00     False
# 13   AHHLD_NUMPER        4.600000e-01     False
# 32       HLTHINS7        3.000000e-01     False
# 6       AHISPANIC        2.760000e-01     False
# 15   AHHLD_NUMKID        9.700000e-02     False
# 31       HLTHINS6        1.800000e-02     False
# 2     ABIRTH_YEAR        1.400000e-02     False
# 4         AGENDER        6.000000e-03     False
# 16  THHLD_NUMADLT        5.000000e-03     False
# 10          AEDUC        2.000000e-03     False
